# %%
import pandas as pd
import numpy as np

# %%
df_zara=pd.read_csv(r"c:\Users\hp\Downloads\zara (1).csv", sep=";")

# Convertir en Excel
df_zara.to_excel("zara.xlsx", index=False)
# Convertir en Json
df_zara.to_json("zara.json", orient="records", indent=4, force_ascii=False)
df_zara
# Out:
#      Product ID Product Position Promotion Product Category Seasonal  \
# 0        185102            Aisle        No         Clothing       No
# 1        188771            Aisle        No         Clothing       No
# 2        180176          End-cap       Yes         Clothing      Yes
# 3        112917            Aisle       Yes         Clothing      Yes
# 4        192936          End-cap        No         Clothing      Yes
# ..          ...              ...       ...              ...      ...
# 247      159182   Front of Store       Yes         Clothing       No
# 248      199233            Aisle       Yes         Clothing       No
# 249      137044            Aisle        No         Clothing      Yes
# 250      154736   Front of Store       Yes         Clothing      Yes
# 251      141434   Front of Store        No         Clothing      Yes
#
#      Sales Volume brand                                                url  \
# ...

# %%
df_zara.describe(include="all")
# Out:
#            Product ID Product Position Promotion Product Category Seasonal  \
# count      252.000000              252       252              252      252
# unique            NaN                3         2                1        2
# top               NaN            Aisle        No         Clothing      Yes
# freq              NaN               97       132              252      128
# mean    153370.503968              NaN       NaN              NaN      NaN
# std      26160.444549              NaN       NaN              NaN      NaN
# min     110075.000000              NaN       NaN              NaN      NaN
# 25%     131053.750000              NaN       NaN              NaN      NaN
# 50%     151681.500000              NaN       NaN              NaN      NaN
# 75%     175669.750000              NaN       NaN              NaN      NaN
# max     199631.000000              NaN       NaN              NaN      NaN
#
# ...

# %%
df_zara_copy = df_zara.copy()

# %%
df_zara_copy_num = df_zara_copy.select_dtypes(include="number")
df_zara_copy_num.columns
# Out:
# Index(['Product ID', 'Sales Volume', 'price'], dtype='object')

# %%
df_zara_copy_ctg = df_zara_copy.select_dtypes(exclude="number")

# %%
df_zara_copy_ctg.mode()
# Out:
#    Product Position Promotion Product Category Seasonal brand  \
# 0             Aisle        No         Clothing      Yes  Zara
# 1               NaN       NaN              NaN      NaN   NaN
# 2               NaN       NaN              NaN      NaN   NaN
# 3               NaN       NaN              NaN      NaN   NaN
# 4               NaN       NaN              NaN      NaN   NaN
# 5               NaN       NaN              NaN      NaN   NaN
# 6               NaN       NaN              NaN      NaN   NaN
# 7               NaN       NaN              NaN      NaN   NaN
# 8               NaN       NaN              NaN      NaN   NaN
# 9               NaN       NaN              NaN      NaN   NaN
# 10              NaN       NaN              NaN      NaN   NaN
# 11              NaN       NaN              NaN      NaN   NaN
# 12              NaN       NaN              NaN      NaN   NaN
# 13              NaN       NaN              NaN      NaN   NaN
# ...

# %%
df_zara_copy_num.mean()
# Out:
# Product ID      153370.503968
# Sales Volume      1823.702381
# price               86.252540
# dtype: float64

# %%
df_zara_copy_num.median()
# Out:
# Product ID      151681.5
# Sales Volume      1839.5
# price               79.9
# dtype: float64

# %%
df_zara_copy_num.mode()
# Out:
#      Product ID  Sales Volume  price
# 0        110075        1466.0   89.9
# 1        110295           NaN    NaN
# 2        110329           NaN    NaN
# 3        110805           NaN    NaN
# 4        111521           NaN    NaN
# ..          ...           ...    ...
# 247      198375           NaN    NaN
# 248      199233           NaN    NaN
# 249      199279           NaN    NaN
# 250      199368           NaN    NaN
# 251      199631           NaN    NaN
#
# [252 rows x 3 columns]

# %%
etendue = df_zara_copy_num.max() - df_zara_copy_num.min()
print(etendue)
# Out:
# Product ID      89556.00
# Sales Volume     2460.00
# price             431.01
# dtype: float64

# %%
df_zara_copy_num.var()
# Out:
# Product ID      6.843689e+08
# Sales Volume    4.867905e+05
# price           2.712660e+03
# dtype: float64

# %%
df_zara_copy_num.std
# Out:
# <bound method DataFrame.std of      Product ID  Sales Volume   price
# 0        185102          2823   19.99
# 1        188771           654  169.00
# 2        180176          2220  129.00
# 3        112917          1568  129.00
# 4        192936          2942  139.00
# ..          ...           ...     ...
# 247      159182          1014  169.00
# 248      199233          2222  159.00
# 249      137044          2534   12.99
# 250      154736          1466   19.90
# 251      141434          2870   39.90
#
# [252 rows x 3 columns]>

# %%
df_zara_copy_num.quantile([0.25, 0.5, 0.75])
# Out:
#       Product ID  Sales Volume  price
# 0.25   131053.75       1243.00   49.9
# 0.50   151681.50       1839.50   79.9
# 0.75   175669.75       2398.75  109.0

# %%
IQR = df_zara_copy_num.quantile(0.75)-df_zara_copy_num.quantile(0.25)
print(IQR)
# Out:
# Product ID      44616.00
# Sales Volume     1155.75
# price              59.10
# dtype: float64

# %%
cov_matrice=df_zara_copy_num.cov()
print(cov_matrice)
# Out:
#                 Product ID  Sales Volume          price
# Product ID    6.843689e+08 -2.197917e+06 -100583.842122
# Sales Volume -2.197917e+06  4.867905e+05   -2593.075456
# price        -1.005838e+05 -2.593075e+03    2712.660199

# %%
corr_matrix = df_zara_copy_num.corr()
print(corr_matrix)
# Out:
#               Product ID  Sales Volume     price
# Product ID      1.000000     -0.120419 -0.073822
# Sales Volume   -0.120419      1.000000 -0.071359
# price          -0.073822     -0.071359  1.000000

# %%
df_zara_copy_mq=df_zara_copy.dropna()

# %%
df_zara_copy_mq.isna().sum()
# Out:
# Product ID          0
# Product Position    0
# Promotion           0
# Product Category    0
# Seasonal            0
# Sales Volume        0
# brand               0
# url                 0
# sku                 0
# name                0
# description         0
# price               0
# currency            0
# scraped_at          0
# terms               0
# section             0
# dtype: int64

# %%
df_zara_copy_mq.to_csv("zara_apres_traitement.csv")
